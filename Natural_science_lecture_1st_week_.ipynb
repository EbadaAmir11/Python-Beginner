# %% [markdown]
# <a href="https://colab.research.google.com/github/EbadaAmir11/Python-Beginner/blob/main/Natural_science_lecture_1st_week_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Basics — Practice Problems
Write a program to input 2 numbers & print their sum.'''

a = int(input("Enter a number = "))
b = int(input("Enter another number = "))
sum = a + b
print("Total sum =",sum)
# Out:
# Enter a number = 6
# Enter another number = 6
# Total sum = 12

# %%
#Write a program to input the side of a square & print its area.
#Area of square = a^2

sides_of_square = input("Enter sides of square = ")
area = int(sides_of_square) **2
print("Area of square =",area)
# Out:
# Enter sides of square = 4
# Area of square = 16

# %%
#Write a program to input 2 floating-point numbers & print their average.

a = float(input("Enter a number = "))
b = float(input("Enter another number = "))
average = (a + b)/2
print("Average =",average)
# Out:
# Enter a number = 10
# Enter another number = 12
# Average = 11.0

# %%
#Write a program to input 2 int numbers, a and b. Print True if a >= b, else print False.

a = int(input("Enter a number = "))
b = int(input("Enter another number = "))
print(a>= b)

'''or
if a >= b:
   print(True)
else:
  print(False)'''
# Out:
# Enter a number = 3
# Enter another number = 4
# False
# 'or\nif a >= b:\n   print(True)\nelse:\n  print(False)'

# %%
'''Write a Python program that takes a string input from the user (e.g., "Python") and prints:'''

#1. The first character of the string.

name = "Ebada Amir"
print(name[0])



#2. The last character using a negative index.

name = "Ebada Amir"
print(name[-1])



#3. The first three characters using slicing.'''
#start:end:step

name = "Ebada Amir"
print(name[0:3:1])
# Out:
# E
# r
# Eba

# %%
'''Write a Python program that inputs an item name, its price (float), and quantity (int). Your program should:'''

#1. Combine the item name with the word "Store" using string concatenation (+) to create a header (e.g., "Notebook Store").
item_name = input("Enter an item name : ")
header = item_name + " Store"
print(header)


#2. Calculate the total cost ($\text{price} \times \text{quantity}$).

item_price =  float(input("Enter price of the item : "))
item_quantity = int(input("Enter the quantity of the item : "))
total_cost =  item_price * item_quantity
print("Total cost =",total_cost)

#3. Use an f-string to print a formatted message like:
#"You bought 2 Notebooks for a total of $6.0"

print(f"You bought {item_quantity} {item_name} for a total of {total_cost}")
# Out:
# Enter an item name : bread
# bread Store
# Enter price of the item : 1
# Enter the quantity of the item : 1
# Total cost = 1.0
# You bought 1 bread for a total of 1.0

# %%
#assignment 2
'''1. Store the word "Programming" in a variable and print:
• The first three characters
• The last three characters
• Characters from index 3 to 7'''


print("hello world")
variable = "Programming"
print(variable[0:3])  #The first three characters

print(variable[8:11])  #The last three characters

print(variable[3:7])  #Characters from index 3 to 7


# Predict the output before running:

text = "Python"

print(text[1:-1])
# Out:
# hello world
# Pro
# ing
# gram
# ytho

# %%
'''3. Create a list:

numbers = [10, 20, 30, 40, 50, 60]
Print:
• First element
• Middle element
• Last element
'''

numbers = [10, 20, 30, 40, 50, 60]

print(numbers[0])
print(numbers[2])
print(numbers[5])
# Out:
# 10
# 30
# 60

# %%
'''Ask the user to enter a word and print:
• First character
• Last character
• The word without the first and last character'''


word = input("Enter a word")
print(word[0])
print(word[-1])
print(word[1:-1])
# Out:
# Enter a wordebada
# e
# a
# bad

# %%
word = "Developer"
print(word[::2])
# Out:
# Dvlpr

# %%
#6. Store "Artificial Intelligence" in a variable and print only "Artificial" using slicing.

text = "Artificial Intelligence"
print(text[0:10])
# Out:
# Artificial

# %%
#7. Create a list of 6 numbers and print the list in reverse order using slicing.

list = [1, 2, 3, 4, 5, 6]
print(list[::-1])
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
'''8. Ask the user to enter their name and print:
• First two letters
• Last two letters'''

name = (input("Enter you name"))
print(name[0:2])

print(name[-2::])
# Out:
# Enter you nameebada
# eb
# da

# %%
#9.
''' Given:values = [5, 15, 25, 35, 45]
Print all elements except the first one.'''

values = [5, 15, 25, 35, 45]
print(values[1:5])
# Out:
# [15, 25, 35, 45]

# %%
#10. Store a sentence in a variable and print every second character.

text = "My name is Ebada Amir"
print(text[::2])
# Out:
# M aei bd mr

# %%
#11.
'''Ask the user to enter a word and check whether its first
 letter equals its last letter'''

word = input("Enter a word")
if word [0] == word[-1] :
 print("True, first and last letter are equal")
else:
  print("False, first and last letter are not equal")
# Out:
# Enter a wordebada
# False, first and last letter are not equal

# %%
#12. Predict the output:

a = 5
b = 10
a, b = b, a
print(a, b)
# Out:
# 10 5

# %%
'''13. Create a list:

data = [2, 4, 6, 8, 10, 12]
Print elements from index 1 to second last element.'''

data = [2, 4, 6, 8, 10, 12]
print(data[1:-1])
# Out:
# [4, 6, 8, 10]

# %%
'''14. Ask the user to enter a word and print characters at even indexes only.'''

word = input("Enter a word")
print(word[::2])
# Out:
# Enter a wordebada
# eaa

# %%
'''15. Given:

nums = [1, 2, 3, 4, 5, 6, 7]
Print:
• First half of the list
'''
nums = [1, 2, 3, 4, 5, 6, 7]
print(nums[:3])
# Out:
# [1, 2, 3]

# %%
'''Scenario
You are working in a science laboratory. A student enters sample information with messy spacing and inconsistent capitalization.
Write a Python program that takes:
student_name as input
sample_name as input
description as input
Your program should:
Remove extra spaces from the inputs.
Display the student's name in uppercase.
Display the first 3 characters of the sample name.
Count how many times the word "water" appears in the description.
Replace "water" with "H2O" in the description.
Display the final information neatly using an f-string.
Example
Input:
Name: ali ahmed
Sample: water sample
Description: this water contains water
Output:
Student: ALI AHMED
Sample Code: wat
Water Count: 2
Updated Description: this H2O contains H2O
Requirement
Use the string methods/concepts taught in session
No loops, functions, or lists required.
'''

student_name.strip() == input("Enter your name")
sample_name.strip() == input("Enter sample name")
description.strip() == input("Enter description")



#output
print("Name:",student_name.upper())

print("Sample code:",sample_name[0:3])

print("WaterCount:",description.count("water"))



print(f"Updated Description:",description.replace("water","H2O"))
# Out:
# Enter your name    ebada
# Enter sample name    water
# Enter descriptionwater is water
# Name: EBADA AMIR
# Sample code: wat
# WaterCount: 2
# Updated Description: H2O is H2O
